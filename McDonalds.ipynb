# %% [markdown]
# <a href="https://colab.research.google.com/github/Antonio-Martinez-Sanchez/McDonalds/blob/main/McDonalds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Image("Mcdonalds_logo.png", width=600)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(color_codes=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b94b1fdb-9936-452b-a617-272cb5ddd4d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b94b1fdb-9936-452b-a617-272cb5ddd4d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving McD.csv to McD.csv

# %%
df = pd.read_csv('McD.csv')

# %%
df.head()
# Out:
#     Category  ... Iron (% Daily Value)
# 0  Breakfast  ...                   15
# 1  Breakfast  ...                    8
# 2  Breakfast  ...                   10
# 3  Breakfast  ...                   15
# 4  Breakfast  ...                   10
#
# [5 rows x 24 columns]

# %%
n_data = len(df)
print(f"We have {n_data} data rows.")
# Out:
# We have 260 data rows.

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
df.describe(). T
# Out:
#                                count        mean  ...     75%     max
# Calories                       260.0  368.269231  ...  500.00  1880.0
# Calories from Fat              260.0  127.096154  ...  200.00  1060.0
# Total Fat                      260.0   14.165385  ...   22.25   118.0
# Total Fat (% Daily Value)      260.0   21.815385  ...   35.00   182.0
# Saturated Fat                  260.0    6.007692  ...   10.00    20.0
# Saturated Fat (% Daily Value)  260.0   29.965385  ...   48.00   102.0
# Trans Fat                      260.0    0.203846  ...    0.00     2.5
# Cholesterol                    260.0   54.942308  ...   65.00   575.0
# Cholesterol (% Daily Value)    260.0   18.392308  ...   21.25   192.0
# Sodium                         260.0  495.750000  ...  865.00  3600.0
# Sodium (% Daily Value)         260.0   20.676923  ...   36.25   150.0
# Carbohydrates                  260.0   47.346154  ...   60.00   141.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
df.dtypes
# Out:
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# Total Fat                        float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# Calcium (% Daily Value)            int64
# ...

# %%
df.shape
# Out:
# (260, 24)

# %%
df.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Beverages             27
# Chicken & Fish        27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
df['Category'].nunique()
# Out:
# 9

# %%
plt.figure(figsize=(20,7))


df["Category"].hist()

# %%
plt.figure(figsize=(20,7))

sns.boxplot(data=df[['Calories','Calories from Fat','Total Fat','Saturated Fat']]);

# %%
correlation = df.corr()

correlation
# Out:
#                                Calories  ...  Iron (% Daily Value)
# Calories                       1.000000  ...              0.643552
# Calories from Fat              0.904588  ...              0.735894
# Total Fat                      0.904409  ...              0.734685
# Total Fat (% Daily Value)      0.904123  ...              0.735478
# Saturated Fat                  0.845564  ...              0.578062
# Saturated Fat (% Daily Value)  0.847631  ...              0.580488
# Trans Fat                      0.522441  ...              0.325476
# Cholesterol                    0.596399  ...              0.655000
# Cholesterol (% Daily Value)    0.595208  ...              0.653167
# Sodium                         0.712309  ...              0.871593
# Sodium (% Daily Value)         0.713415  ...              0.870742
# Carbohydrates                  0.781539  ...              0.210241
# Carbohydrates (% Daily Value)  0.781242  ...              0.210643
# ...

# %%
plt.figure(figsize=(15,11))


sns.heatmap(correlation,annot = True)

# %%
df['Category'].unique()

from pandas import DataFrame

Category_List = sorted(df['Category'].unique())

type(sorted(df['Category'].unique()))

a = pd.DataFrame(Category_List,columns=[''] )  

a.index += 1

print('\n \n  Let us view the different food categories that are available to us :- \n \n  ',a )
# Out:
#
#   Let us view the different food categories that are available to us :-
#
#
# 1         Beef & Pork
# 2           Beverages
# 3           Breakfast
# 4      Chicken & Fish
# 5        Coffee & Tea
# 6            Desserts
# 7              Salads
# 8  Smoothies & Shakes
# 9      Snacks & Sides

# %%
b = pd.pivot_table(df, 'Cholesterol (% Daily Value)', index=['Category'])


Result = b.sort_values(('Cholesterol (% Daily Value)'), ascending=False)

Result
# Out:
#                     Cholesterol (% Daily Value)
# Category
# Breakfast                             50.952381
# Beef & Pork                           28.933333
# Chicken & Fish                        25.222222
# Salads                                17.333333
# Smoothies & Shakes                    14.714286
# Coffee & Tea                           9.378947
# Snacks & Sides                         6.230769
# Desserts                               4.857143
# Beverages                              0.185185

# %%
b = pd.pivot_table(df, 'Calories', index=['Category'])


Result = b.sort_values(('Calories'), ascending=False)

Result
# Out:
#                       Calories
# Category
# Chicken & Fish      552.962963
# Smoothies & Shakes  531.428571
# Breakfast           526.666667
# Beef & Pork         494.000000
# Coffee & Tea        283.894737
# Salads              270.000000
# Snacks & Sides      245.769231
# Desserts            222.142857
# Beverages           113.703704

# %%
b = pd.pivot_table(df, 'Sugars', index=['Category'])


Result = b.sort_values(('Sugars'), ascending=False)

Result
# Out:
#                        Sugars
# Category
# Smoothies & Shakes  77.892857
# Coffee & Tea        39.610526
# Beverages           27.851852
# Desserts            26.142857
# Beef & Pork          8.800000
# Breakfast            8.261905
# Chicken & Fish       7.333333
# Salads               6.833333
# Snacks & Sides       4.076923

# %%
b = pd.pivot_table(df, 'Saturated Fat (% Daily Value)', index=['Category'])


Result = b.sort_values(('Saturated Fat (% Daily Value)'), ascending=False)

Result
# Out:
#                     Saturated Fat (% Daily Value)
# Category
# Breakfast                               53.428571
# Beef & Pork                             52.000000
# Smoothies & Shakes                      41.785714
# Chicken & Fish                          31.111111
# Coffee & Tea                            24.368421
# Desserts                                21.285714
# Salads                                  18.500000
# Snacks & Sides                          13.384615
# Beverages                                0.296296

# %%
df['Item'].head(16)
# Out:
# 0                                          Egg McMuffin
# 1                                     Egg White Delight
# 2                                      Sausage McMuffin
# 3                             Sausage McMuffin with Egg
# 4                      Sausage McMuffin with Egg Whites
# 5                                  Steak & Egg McMuffin
# 6         Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7           Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8     Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9     Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 10                    Sausage Biscuit (Regular Biscuit)
# 11                      Sausage Biscuit (Large Biscuit)
# 12           Sausage Biscuit with Egg (Regular Biscuit)
# 13             Sausage Biscuit with Egg (Large Biscuit)
# 14    Sausage Biscuit with Egg Whites (Regular Biscuit)
# 15      Sausage Biscuit with Egg Whites (Large Biscuit)
# Name: Item, dtype: object

# %% [markdown]
# Salads are by far the best Category in the Menu but does it mean the best profitable Category?

# %%
values = df['Category'].value_counts().sort_values(ascending=False)
labels = values.index
clrs=["red"]
sns.set_style("white")
plt.figure(figsize = (15,5))
sns.barplot(y=values, x=labels, palette=clrs)
plt.xticks(rotation=50)
plt.xlabel('Category')
plt.ylabel('Calories')
plt.title('Calories vs Category McDonals Menu');

plt.show()

# %%
c = pd.pivot_table(df, 'Sodium', index=['Item'])


Result_1 = c.sort_values(('Sodium'), ascending=False)


Result_1.head(15)
# Out:
#                                                     Sodium
# Item
# Chicken McNuggets (40 piece)                          3600
# Big Breakfast with Hotcakes and Egg Whites (Lar...    2290
# Big Breakfast with Hotcakes (Large Biscuit)           2260
# Big Breakfast with Hotcakes and Egg Whites (Reg...    2170
# Big Breakfast with Hotcakes (Regular Biscuit)         2150
# Chicken McNuggets (20 piece)                          1800
# Bacon Clubhouse Crispy Chicken Sandwich               1720
# Big Breakfast with Egg Whites (Large Biscuit)         1700
# Big Breakfast (Large Biscuit)                         1680
# Big Breakfast with Egg Whites (Regular Biscuit)       1590
# Bacon Clubhouse Grilled Chicken Sandwich              1560
# Big Breakfast (Regular Biscuit)                       1560
# Premium McWrap Chicken & Bacon (Crispy Chicken)       1540
# Steak, Egg & Cheese Bagel                             1510
# Bacon, Egg & Cheese Bagel with Egg Whites             1480

# %% [markdown]
# Three major components are analyzed in this Python exercise: Sodium, Cholestherol and Saturated Fats. Considering the different Categories, Breakfast is the Category with the highest level of Cholesterol and Saturated Fat. Chicken & Fish is the Category with the highest level of Sodium.

# %%
c = pd.pivot_table(df, 'Sodium', index=['Category'])


Result_1 = c.sort_values(('Sodium'), ascending=False)


Result_1.head(15)
# Out:
#                          Sodium
# Category
# Chicken & Fish      1257.777778
# Breakfast           1211.071429
# Beef & Pork         1020.666667
# Salads               588.333333
# Snacks & Sides       395.769231
# Smoothies & Shakes   183.571429
# Coffee & Tea         136.894737
# Desserts             117.142857
# Beverages             41.481481

# %%
c = pd.pivot_table(df, 'Saturated Fat', index=['Category'])


Result_1 = c.sort_values(('Saturated Fat'), ascending=False)


Result_1.head(15)
# Out:
#                     Saturated Fat
# Category
# Breakfast               10.654762
# Beef & Pork             10.466667
# Smoothies & Shakes       8.375000
# Chicken & Fish           6.166667
# Coffee & Tea             4.921053
# Desserts                 4.285714
# Salads                   3.750000
# Snacks & Sides           2.692308
# Beverages                0.055556

# %%
c = pd.pivot_table(df, 'Cholesterol', index=['Category'])


Result_1 = c.sort_values(('Cholesterol'), ascending=False)


Result_1.head(15)
# Out:
#                     Cholesterol
# Category
# Breakfast            152.857143
# Beef & Pork           87.333333
# Chicken & Fish        75.370370
# Salads                51.666667
# Smoothies & Shakes    45.000000
# Coffee & Tea          27.263158
# Snacks & Sides        18.461538
# Desserts              15.000000
# Beverages              0.555556

# %% [markdown]
# McDonalds Menu  is well known by its High Saturated Fats, Sodium and Sugars. What else do we have in the Menu? SURPRISE, SURPRISE SALADS might dissapear from the Menu as stated: https://www.eatthis.com/mcdonalds-ditched-salads/

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eed036e7-4661-4855-9064-72c6d2cdd670" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eed036e7-4661-4855-9064-72c6d2cdd670">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Mcdonalds_logo.png to Mcdonalds_logo.png
